# %% [markdown]
# <a href="https://colab.research.google.com/github/adithya-prabhu-22/ml_lab_2_4NI23CI007_adithya/blob/main/ml_lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/content/Data.csv")


numerical_cols_with_missing = [' StudyHours', ' Attendance', ' Marks']
for col in numerical_cols_with_missing:

    df[col] = pd.to_numeric(df[col].replace('', np.nan), errors='coerce')

    df[col] = df[col].fillna(df[col].mean())


categorical_cols_with_missing = [' Gender', ' Result']
for col in categorical_cols_with_missing:

    df[col] = df[col].astype(str).str.strip().replace('', np.nan)

    mode_val = df[col].mode()[0]
    df[col] = df[col].fillna(mode_val)


df
# Out:
#    St_ID   Age  Gender   StudyHours   Attendance      Marks  Result
# 0      1    18  Female     2.500000    75.000000  55.000000    Pass
# 1      2    19    Male     5.000000    82.000000  68.000000    Pass
# 2      3    18  Female     3.888889    68.000000  61.000000    Pass
# 3      4    20    Male     2.000000    91.000000  90.000000    Pass
# 4      5    19  Female     5.000000    88.000000  78.000000    Pass
# 5      6    18    Male     1.500000    60.000000  45.000000    Fail
# 6      7    21  Female     7.000000    77.555556  92.000000    Pass
# 7      8    20    Male     4.500000    90.000000  72.000000    Pass
# 8      9    20    Male     4.500000    80.000000  72.000000    Pass
# 9     10    18    Male     3.000000    64.000000  70.333333    Fail

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder
import pandas as pd

X = df[[' Age', ' Gender', ' StudyHours', ' Attendance', ' Marks']]
y = df[' Result']


X = pd.get_dummies(X, columns=[' Gender'], drop_first=True)


le = LabelEncoder()
y_encoded = le.fit_transform(y)


X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.3, random_state=42)
model = LogisticRegression(solver='liblinear', random_state=42)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred, target_names=le.classes_)

print(f"Model Accuracy: {accuracy:.2f}")
print("\nClassification Report:")
print(report)
# Out:
# Model Accuracy: 0.67
#
# Classification Report:
#               precision    recall  f1-score   support
#
#         Fail       0.00      0.00      0.00         1
#         Pass       0.67      1.00      0.80         2
#
#     accuracy                           0.67         3
#    macro avg       0.33      0.50      0.40         3
# weighted avg       0.44      0.67      0.53         3
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
